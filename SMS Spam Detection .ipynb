# %%
pip install pandas
# Out:
# ...
#
# ...

# %%
import pandas as pd

# %%
import numpy as np

# %%
df= pd.read_csv('spam.csv', encoding= ('ISO-8859-1'))

# %%
df
# Out:
#         v1                                                 v2 Unnamed: 2  \
# 0      ham  Go until jurong point, crazy.. Available only ...        NaN
# 1      ham                      Ok lar... Joking wif u oni...        NaN
# 2     spam  Free entry in 2 a wkly comp to win FA Cup fina...        NaN
# 3      ham  U dun say so early hor... U c already then say...        NaN
# 4      ham  Nah I don't think he goes to usf, he lives aro...        NaN
# ...    ...                                                ...        ...
# 5567  spam  This is the 2nd time we have tried 2 contact u...        NaN
# 5568   ham              Will Ì_ b going to esplanade fr home?        NaN
# 5569   ham  Pity, * was in mood for that. So...any other s...        NaN
# 5570   ham  The guy did some bitching but I acted like i'd...        NaN
# 5571   ham                         Rofl. Its true to its name        NaN
#
#      Unnamed: 3 Unnamed: 4
# 0           NaN        NaN
# 1           NaN        NaN
# ...

# %%
df.head()
# Out:
#      v1                                                 v2 Unnamed: 2  \
# 0   ham  Go until jurong point, crazy.. Available only ...        NaN
# 1   ham                      Ok lar... Joking wif u oni...        NaN
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...        NaN
# 3   ham  U dun say so early hor... U c already then say...        NaN
# 4   ham  Nah I don't think he goes to usf, he lives aro...        NaN
#
#   Unnamed: 3 Unnamed: 4
# 0        NaN        NaN
# 1        NaN        NaN
# 2        NaN        NaN
# 3        NaN        NaN
# 4        NaN        NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5572 entries, 0 to 5571
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   v1          5572 non-null   object
#  1   v2          5572 non-null   object
#  2   Unnamed: 2  50 non-null     object
#  3   Unnamed: 3  12 non-null     object
#  4   Unnamed: 4  6 non-null      object
# dtypes: object(5)
# memory usage: 217.8+ KB

# %%
df.tail()
# Out:
#         v1                                                 v2 Unnamed: 2  \
# 5567  spam  This is the 2nd time we have tried 2 contact u...        NaN
# 5568   ham              Will Ì_ b going to esplanade fr home?        NaN
# 5569   ham  Pity, * was in mood for that. So...any other s...        NaN
# 5570   ham  The guy did some bitching but I acted like i'd...        NaN
# 5571   ham                         Rofl. Its true to its name        NaN
#
#      Unnamed: 3 Unnamed: 4
# 5567        NaN        NaN
# 5568        NaN        NaN
# 5569        NaN        NaN
# 5570        NaN        NaN
# 5571        NaN        NaN

# %%
df.dtypes
# Out:
# v1            object
# v2            object
# Unnamed: 2    object
# Unnamed: 3    object
# Unnamed: 4    object
# dtype: object

# %%
#drop last 3 columns

# %%
df.drop(columns= ['Unnamed: 2' ,'Unnamed: 3','Unnamed: 4'] , inplace = True)

# %%
df.sample(5)
# Out:
#         v1                                                 v2
# 4043   ham                              Yes, my reg is  Ciao!
# 1066   ham       Once free call me sir. I am waiting for you.
# 1186   ham   Goodmorning, Today i am late for  &lt;#&gt; min.
# 2063  spam  URGENT! Your mobile No *********** WON a å£2,0...
# 583    ham  my ex-wife was not able to have kids. Do you w...

# %%
#rename the column

# %%
df.rename(columns={'v1' : 'focus', 'v2' : 'write'} , inplace = True)

# %%
df.sample(5)
# Out:
#      focus                                              write
# 614    ham  I called and said all to him:)then he have to ...
# 964    ham                             Are you this much buzy
# 5039  spam  Natalie (20/F) is inviting you to be her frien...
# 2595  spam  Sunshine Quiz Wkly Q! Win a top Sony DVD playe...
# 3211   ham                  We got a divorce. Lol. She.s here

# %%
pip install --upgrade scikit-learn
# Out:
# ...
#   Obtaining dependency information for scikit-learn from https://files.pythonhosted.org/packages/a8/e9/3e4879974a7c4dcaca2a746dde3df08d0ae8f14c74b03591616ce5f0a8b1/scikit_learn-1.4.0-1-cp311-cp311-win_amd64.whl.metadata
# ...
#    ---------------------------------------- 0.0/10.6 MB ? eta -:--:--
#    ---------------------------------------- 0.1/10.6 MB 1.1 MB/s eta 0:00:10
#    ---------------------------------------- 0.1/10.6 MB 1.1 MB/s eta 0:00:11
#     --------------------------------------- 0.2/10.6 MB 1.1 MB/s eta 0:00:10
#     --------------------------------------- 0.2/10.6 MB 1.3 MB/s eta 0:00:09
#    - -------------------------------------- 0.3/10.6 MB 1.3 MB/s eta 0:00:08
#    - -------------------------------------- 0.4/10.6 MB 1.4 MB/s eta 0:00:08
#    - -------------------------------------- 0.4/10.6 MB 1.3 MB/s eta 0:00:08
#    -- ------------------------------------- 0.5/10.6 MB 1.4 MB/s eta 0:00:08
# ...

# %%
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()

# %%
df
# Out:
#      focus                                              write
# 0      ham  Go until jurong point, crazy.. Available only ...
# 1      ham                      Ok lar... Joking wif u oni...
# 2     spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3      ham  U dun say so early hor... U c already then say...
# 4      ham  Nah I don't think he goes to usf, he lives aro...
# ...    ...                                                ...
# 5567  spam  This is the 2nd time we have tried 2 contact u...
# 5568   ham              Will Ì_ b going to esplanade fr home?
# 5569   ham  Pity, * was in mood for that. So...any other s...
# 5570   ham  The guy did some bitching but I acted like i'd...
# 5571   ham                         Rofl. Its true to its name
#
# [5572 rows x 2 columns]

# %%
df['focus']= encoder.fit_transform(df['focus'])

# %%
df.head()
# Out:
#    focus                                              write
# 0      0  Go until jurong point, crazy.. Available only ...
# 1      0                      Ok lar... Joking wif u oni...
# 2      1  Free entry in 2 a wkly comp to win FA Cup fina...
# 3      0  U dun say so early hor... U c already then say...
# 4      0  Nah I don't think he goes to usf, he lives aro...

# %%
df.isnull().sum()
# Out:
# focus    0
# write    0
# dtype: int64

# %%
#check for duplicates values

# %%
df.duplicated().sum()
# Out:
# 403

# %%
df=df.drop_duplicates(keep= 'first')

# %%
df
# Out:
#       focus                                              write
# 0         0  Go until jurong point, crazy.. Available only ...
# 1         0                      Ok lar... Joking wif u oni...
# 2         1  Free entry in 2 a wkly comp to win FA Cup fina...
# 3         0  U dun say so early hor... U c already then say...
# 4         0  Nah I don't think he goes to usf, he lives aro...
# ...     ...                                                ...
# 5567      1  This is the 2nd time we have tried 2 contact u...
# 5568      0              Will Ì_ b going to esplanade fr home?
# 5569      0  Pity, * was in mood for that. So...any other s...
# 5570      0  The guy did some bitching but I acted like i'd...
# 5571      0                         Rofl. Its true to its name
#
# [5169 rows x 2 columns]

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.shape
# Out:
# (5169, 2)

# %% [markdown]
# # EDA

# %%
df.head()
# Out:
#    focus                                              write
# 0      0  Go until jurong point, crazy.. Available only ...
# 1      0                      Ok lar... Joking wif u oni...
# 2      1  Free entry in 2 a wkly comp to win FA Cup fina...
# 3      0  U dun say so early hor... U c already then say...
# 4      0  Nah I don't think he goes to usf, he lives aro...

# %%
df['focus'].value_counts()
# Out:
# focus
# 0    4516
# 1     653
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
plt.pie(df['focus'].value_counts(), labels= ['ham' , 'spam'], autopct= "%0.2f")
plt.show()

# %%
 #Data is imbalanced

# %%
import nltk

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\ayush\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# True

# %%
df
# Out:
#       focus                                              write
# 0         0  Go until jurong point, crazy.. Available only ...
# 1         0                      Ok lar... Joking wif u oni...
# 2         1  Free entry in 2 a wkly comp to win FA Cup fina...
# 3         0  U dun say so early hor... U c already then say...
# 4         0  Nah I don't think he goes to usf, he lives aro...
# ...     ...                                                ...
# 5567      1  This is the 2nd time we have tried 2 contact u...
# 5568      0              Will Ì_ b going to esplanade fr home?
# 5569      0  Pity, * was in mood for that. So...any other s...
# 5570      0  The guy did some bitching but I acted like i'd...
# 5571      0                         Rofl. Its true to its name
#
# [5169 rows x 2 columns]

# %%
df['number_characters']= df['write'].apply(len)
# Out:
# C:\Users\ayush\AppData\Local\Temp\ipykernel_31356\2358711334.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['number_characters']= df['write'].apply(len)

# %%
df.head()
# Out:
#    focus                                              write  number_characters
# 0      0  Go until jurong point, crazy.. Available only ...                111
# 1      0                      Ok lar... Joking wif u oni...                 29
# 2      1  Free entry in 2 a wkly comp to win FA Cup fina...                155
# 3      0  U dun say so early hor... U c already then say...                 49
# 4      0  Nah I don't think he goes to usf, he lives aro...                 61

# %%
# the mumber of words
df['words']= df['write'].apply(lambda x:len(nltk.word_tokenize(x)))
# Out:
# C:\Users\ayush\AppData\Local\Temp\ipykernel_31356\2959215662.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['words']= df['write'].apply(lambda x:len(nltk.word_tokenize(x)))

# %%
df.head()
# Out:
#    focus                                              write  \
# 0      0  Go until jurong point, crazy.. Available only ...
# 1      0                      Ok lar... Joking wif u oni...
# 2      1  Free entry in 2 a wkly comp to win FA Cup fina...
# 3      0  U dun say so early hor... U c already then say...
# 4      0  Nah I don't think he goes to usf, he lives aro...
#
#    number_characters  words
# 0                111     24
# 1                 29      8
# 2                155     37
# 3                 49     13
# 4                 61     15

# %%
df['sentance']= df['write'].apply(lambda x:len(nltk.sent_tokenize(x)))
# Out:
# C:\Users\ayush\AppData\Local\Temp\ipykernel_31356\3174279886.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['sentance']= df['write'].apply(lambda x:len(nltk.sent_tokenize(x)))

# %%
df.head()
# Out:
#    focus                                              write  \
# 0      0  Go until jurong point, crazy.. Available only ...
# 1      0                      Ok lar... Joking wif u oni...
# 2      1  Free entry in 2 a wkly comp to win FA Cup fina...
# 3      0  U dun say so early hor... U c already then say...
# 4      0  Nah I don't think he goes to usf, he lives aro...
#
#    number_characters  words  sentance
# 0                111     24         2
# 1                 29      8         2
# 2                155     37         2
# 3                 49     13         1
# 4                 61     15         1

# %%
df[['number_characters' ,'words' , 'sentance']].describe()
# Out:
#        number_characters        words     sentance
# count        5169.000000  5169.000000  5169.000000
# mean           78.977945    18.455794     1.965564
# std            58.236293    13.324758     1.448541
# min             2.000000     1.000000     1.000000
# 25%            36.000000     9.000000     1.000000
# 50%            60.000000    15.000000     1.000000
# 75%           117.000000    26.000000     2.000000
# max           910.000000   220.000000    38.000000

# %%
#ham
df[df['focus']== 0][['number_characters' ,'words' , 'sentance']].describe()
# Out:
#        number_characters        words     sentance
# count        4516.000000  4516.000000  4516.000000
# mean           70.459256    17.123782     1.820195
# std            56.358207    13.493970     1.383657
# min             2.000000     1.000000     1.000000
# 25%            34.000000     8.000000     1.000000
# 50%            52.000000    13.000000     1.000000
# 75%            90.000000    22.000000     2.000000
# max           910.000000   220.000000    38.000000

# %%
#spam
df[df['focus']== 1][['number_characters' ,'words' , 'sentance']].describe()
# Out:
#        number_characters       words    sentance
# count         653.000000  653.000000  653.000000
# mean          137.891271   27.667688    2.970904
# std            30.137753    7.008418    1.488425
# min            13.000000    2.000000    1.000000
# 25%           132.000000   25.000000    2.000000
# 50%           149.000000   29.000000    3.000000
# 75%           157.000000   32.000000    4.000000
# max           224.000000   46.000000    9.000000

# %%
import seaborn as sns

# %%
df[df['focus']==0]['number_characters']
# Out:
# 0       111
# 1        29
# 3        49
# 4        61
# 6        77
#        ...
# 5565     12
# 5568     37
# 5569     57
# 5570    125
# 5571     26
# Name: number_characters, Length: 4516, dtype: int64

# %%
sns.histplot(df[df['focus']==0]['number_characters'])
sns.histplot(df[df['focus']==1]['number_characters'], color = 'red')
# Out:
# <Axes: xlabel='number_characters', ylabel='Count'>

# %%
plt.figure(figsize=(12,6))
sns.histplot(df[df['focus']==0]['number_characters'])
sns.histplot(df[df['focus']==1]['number_characters'], color = 'red')
# Out:
# <Axes: xlabel='number_characters', ylabel='Count'>

# %%
plt.figure(figsize=(12,6))
sns.histplot(df[df['focus']==0]['words'])
sns.histplot(df[df['focus']==1]['words'], color = 'red')
# Out:
# <Axes: xlabel='words', ylabel='Count'>

# %%
sns.pairplot(df,hue='focus')
# Out:
# C:\Users\ayush\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
numeric_df = df.select_dtypes(include=['float64', 'int64'])

# %%
df
# Out:
#       focus                                              write  \
# 0         0  Go until jurong point, crazy.. Available only ...
# 1         0                      Ok lar... Joking wif u oni...
# 2         1  Free entry in 2 a wkly comp to win FA Cup fina...
# 3         0  U dun say so early hor... U c already then say...
# 4         0  Nah I don't think he goes to usf, he lives aro...
# ...     ...                                                ...
# 5567      1  This is the 2nd time we have tried 2 contact u...
# 5568      0              Will Ì_ b going to esplanade fr home?
# 5569      0  Pity, * was in mood for that. So...any other s...
# 5570      0  The guy did some bitching but I acted like i'd...
# 5571      0                         Rofl. Its true to its name
#
#       number_characters  words  sentance
# 0                   111     24         2
# 1                    29      8         2
# 2                   155     37         2
# 3                    49     13         1
# ...

# %%
#DATA Preprocessing

# %%
pip install nltk
# Out:
# ...
#
# ...

# %%
def transform_text(text):
    text = text.lower()  # Corrected to call the lower() method
    text = nltk.word_tokenize(text)
    return text

# %%
transform_text('Hi how Are you')
# Out:
# ['hi', 'how', 'are', 'you']

# %%
df['write'][2000]
# Out:
# "But i'll b going 2 sch on mon. My sis need 2 take smth."

# %%
def transform_text(text):
    text = text.lower() 
    text = nltk.word_tokenize(text)
    
    y= []
    for i in text:
        if i.isalnum():
            y.append(i)
    text = y[:]
    y.clear()
    
    for i in text:
        if i not in stopwords.words('english') and i not in string.punctuation:
            y.append(i)
    
    text= y[:]
    y.clear()
    for i in text:
        y.append(ns.stem(i))
        
    
    return  " ". join(y)

# %%
import nltk
from nltk.corpus import stopwords
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\ayush\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.
# True

# %%
stopwords.words('english')
# Out:
# ['i',
#  'me',
#  'my',
#  'myself',
#  'we',
#  'our',
#  'ours',
#  'ourselves',
#  'you',
#  "you're",
#  "you've",
#  "you'll",
#  "you'd",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  'he',
#  'him',
#  'his',
#  'himself',
#  'she',
#  "she's",
#  'her',
#  'hers',
#  'herself',
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'they',
#  'them',
#  'their',
#  'theirs',
#  'themselves',
#  'what',
#  'which',
#  'who',
#  'whom',
#  'this',
#  'that',
#  "that'll",
#  'these',
#  'those',
#  'am',
#  'is',
#  'are',
#  'was',
#  'were',
#  'be',
#  'been',
#  'being',
#  'have',
#  'has',
#  'had',
#  'having',
#  'do',
#  'does',
#  'did',
#  'doing',
#  'a',
#  'an',
#  'the',
#  'and',
#  'but',
#  'if',
#  'or',
#  'because',
#  'as',
#  'until',
#  'while',
#  'of',
#  'at',
#  'by',
#  'for',
#  'with',
#  'about',
#  'against',
#  'between',
#  'into',
#  'through',
#  'during',
#  'before',
#  'after',
#  'above',
#  'below',
#  'to',
#  'from',
#  'up',
# ...

# %%
import string 
string.punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
transform_text('Go until jurong point, crazy.. Available only in bugis n great world la e buffet... Cine there got amore wat...')
# Out:
# 'go jurong point crazi avail bugi n great world la e buffet cine got amor wat'

# %%
transform_text("I am gonna be home soon and i don't want to talk about this stuff anymore tonight, k? I've cried enough today.")
# Out:
# 'gon na home soon want talk stuff anymor tonight k cri enough today'

# %%
import nltk.stem.porter

# %%
from nltk.stem.porter import PorterStemmer

# %%
ns= PorterStemmer()
ns.stem('loving')
# Out:
# 'love'

# %%
df['write'][10]
# Out:
# "I'm gonna be home soon and i don't want to talk about this stuff anymore tonight, k? I've cried enough today."

# %%
df['transformed_text']= df['write'].apply(transform_text)
# Out:
# C:\Users\ayush\AppData\Local\Temp\ipykernel_31356\152619578.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['transformed_text' ]= df['write'].apply(transform_text)

# %%
df
# Out:
#       focus                                              write  \
# 0         0  Go until jurong point, crazy.. Available only ...
# 1         0                      Ok lar... Joking wif u oni...
# 2         1  Free entry in 2 a wkly comp to win FA Cup fina...
# 3         0  U dun say so early hor... U c already then say...
# 4         0  Nah I don't think he goes to usf, he lives aro...
# ...     ...                                                ...
# 5567      1  This is the 2nd time we have tried 2 contact u...
# 5568      0              Will Ì_ b going to esplanade fr home?
# 5569      0  Pity, * was in mood for that. So...any other s...
# 5570      0  The guy did some bitching but I acted like i'd...
# 5571      0                         Rofl. Its true to its name
#
#       number_characters  words  sentance  \
# 0                   111     24         2
# 1                    29      8         2
# 2                   155     37         2
# ...

# %%
df.head()
# Out:
#    focus                                              write  \
# 0      0  Go until jurong point, crazy.. Available only ...
# 1      0                      Ok lar... Joking wif u oni...
# 2      1  Free entry in 2 a wkly comp to win FA Cup fina...
# 3      0  U dun say so early hor... U c already then say...
# 4      0  Nah I don't think he goes to usf, he lives aro...
#
#    number_characters  words  sentance  \
# 0                111     24         2
# 1                 29      8         2
# 2                155     37         2
# 3                 49     13         1
# 4                 61     15         1
#
#                                     transformed_text
# 0  go jurong point crazi avail bugi n great world...
# 1                              ok lar joke wif u oni
# 2  free entri 2 wkli comp win fa cup final tkt 21...
# 3                u dun say earli hor u c alreadi say
# 4               nah think goe usf live around though

# %%
pip install wordcloud
# Out:
# ...
#
#   Obtaining dependency information for wordcloud from https://files.pythonhosted.org/packages/f5/b0/247159f61c5d5d6647171bef84430b7efad4db504f0229674024f3a4f7f2/wordcloud-1.9.3-cp311-cp311-win_amd64.whl.metadata
# ...
#    ---------------------------------------- 0.0/300.2 kB ? eta -:--:--
#    ---------------- ----------------------- 122.9/300.2 kB 2.4 MB/s eta 0:00:01
#    ---------------------------------- ----- 256.0/300.2 kB 3.2 MB/s eta 0:00:01
#    ---------------------------------------- 300.2/300.2 kB 2.6 MB/s eta 0:00:00
# ...

# %%
from wordcloud import WordCloud

# %%
wc= WordCloud(width=550, height=550 , min_font_size =10 ,background_color ='black')

# %%
spam_wc= wc.generate(df[df['focus']== 1]['transformed_text'].str.cat(sep= " "))

# %%
plt.imshow(spam_wc)

# %%
ham_wc= wc.generate(df[df['focus']== 0]['transformed_text'].str.cat(sep= " "))

# %%
plt.figure(figsize=(15,5))
plt.imshow(ham_wc)

# %%
df.head()
# Out:
#    focus                                              write  \
# 0      0  Go until jurong point, crazy.. Available only ...
# 1      0                      Ok lar... Joking wif u oni...
# 2      1  Free entry in 2 a wkly comp to win FA Cup fina...
# 3      0  U dun say so early hor... U c already then say...
# 4      0  Nah I don't think he goes to usf, he lives aro...
#
#    number_characters  words  sentance  \
# 0                111     24         2
# 1                 29      8         2
# 2                155     37         2
# 3                 49     13         1
# 4                 61     15         1
#
#                                     transformed_text
# 0  go jurong point crazi avail bugi n great world...
# 1                              ok lar joke wif u oni
# 2  free entri 2 wkli comp win fa cup final tkt 21...
# 3                u dun say earli hor u c alreadi say
# 4               nah think goe usf live around though

# %%
df[df['focus']==1]['transformed_text'].tolist()
# Out:
# ['free entri 2 wkli comp win fa cup final tkt 21st may text fa 87121 receiv entri question std txt rate c appli 08452810075over18',
#  'freemsg hey darl 3 week word back like fun still tb ok xxx std chg send rcv',
#  'winner valu network custom select receivea prize reward claim call claim code kl341 valid 12 hour',
#  'mobil 11 month u r entitl updat latest colour mobil camera free call mobil updat co free 08002986030',
#  'six chanc win cash 100 pound txt csh11 send cost 6day tsandc appli repli hl 4 info',
#  'urgent 1 week free membership prize jackpot txt word claim 81010 c lccltd pobox 4403ldnw1a7rw18',
#  'xxxmobilemovieclub use credit click wap link next txt messag click http',
#  'england v macedonia dont miss news txt ur nation team 87077 eg england 87077 tri wale scotland poboxox36504w45wq',
#  'thank subscript rington uk mobil charg pleas confirm repli ye repli charg',
# ...

# %%
for message in df[df['focus']==1]['transformed_text'].tolist():
    print(message)
# Out:
# free entri 2 wkli comp win fa cup final tkt 21st may text fa 87121 receiv entri question std txt rate c appli 08452810075over18
# freemsg hey darl 3 week word back like fun still tb ok xxx std chg send rcv
# winner valu network custom select receivea prize reward claim call claim code kl341 valid 12 hour
# mobil 11 month u r entitl updat latest colour mobil camera free call mobil updat co free 08002986030
# six chanc win cash 100 pound txt csh11 send cost 6day tsandc appli repli hl 4 info
# urgent 1 week free membership prize jackpot txt word claim 81010 c lccltd pobox 4403ldnw1a7rw18
# xxxmobilemovieclub use credit click wap link next txt messag click http
# england v macedonia dont miss news txt ur nation team 87077 eg england 87077 tri wale scotland poboxox36504w45wq
# thank subscript rington uk mobil charg pleas confirm repli ye repli charg
# 07732584351 rodger burn msg tri call repli sm free nokia mobil free camcord pleas call 08000930705 deliveri tomorrow
# ...

# %%
spam_corpus= []
for message in df[df['focus']==1]['transformed_text'].tolist():
    for word in message.split():
        spam_corpus.append(word)

# %%
len(spam_corpus)
# Out:
# 9939

# %%
from collections import Counter

# %%
from collections import Counter

# %%
ham_corpus= []
for message in df[df['focus']==0]['transformed_text'].tolist():
    for word in message.split():
        ham_corpus.append(word)

# %%
len(ham_corpus)
# Out:
# 35404

# %%
df.head()
# Out:
#    focus                                              write  \
# 0      0  Go until jurong point, crazy.. Available only ...
# 1      0                      Ok lar... Joking wif u oni...
# 2      1  Free entry in 2 a wkly comp to win FA Cup fina...
# 3      0  U dun say so early hor... U c already then say...
# 4      0  Nah I don't think he goes to usf, he lives aro...
#
#    number_characters  words  sentance  \
# 0                111     24         2
# 1                 29      8         2
# 2                155     37         2
# 3                 49     13         1
# 4                 61     15         1
#
#                                     transformed_text
# 0  go jurong point crazi avail bugi n great world...
# 1                              ok lar joke wif u oni
# 2  free entri 2 wkli comp win fa cup final tkt 21...
# 3                u dun say earli hor u c alreadi say
# 4               nah think goe usf live around though

# %% [markdown]
# # Model Bulding

# %%
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer

# %%
cv = CountVectorizer()
tfidf= TfidfVectorizer()

# %%
X= tfidf.fit_transform(df['transformed_text']). toarray()

# %%
X.shape
# Out:
# (5169, 6708)

# %%
y= df['focus']. values

# %%
y
# Out:
# array([0, 0, 1, ..., 0, 0, 0])

# %%
pip install --upgrade scikit-learn
# Out:
# ...
#
# ...

# %%
pip show scikit-learn
# Out:
# Name: scikit-learn
# Version: 1.4.0
# Summary: A set of python modules for machine learning and data mining
# Home-page: https://scikit-learn.org
# Author:
# Author-email:
# License: new BSD
# Location: C:\Users\ayush\anaconda3\Lib\site-packages
# Requires: joblib, numpy, scipy, threadpoolctl
# Required-by: daal4py, imbalanced-learn, scikit-learn-intelex
# Note: you may need to restart the kernel to use updated packages.

# %%
conda install scikit-learn
# Out:
# Note: you may need to restart the kernel to use updated packages.Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Users\ayush\anaconda3
#
#   added / updated specs:
#     - scikit-learn
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     scikit-learn-1.3.0         |  py311hf62ec03_1         8.1 MB
#     ------------------------------------------------------------
#                                            Total:         8.1 MB
#
# The following packages will be UPDATED:
#
#   scikit-learn                        1.3.0-py311hf62ec03_0 --> 1.3.0-py311hf62ec03_1
#
#
#
# ...
#
# scikit-learn-1.3.0   | 8.1 MB    |            |   0%
# scikit-learn-1.3.0   | 8.1 MB    |            |   0%
# scikit-learn-1.3.0   | 8.1 MB    | 3          |   3%
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix, precision_score

# %%
X_train, X_test, y_train, y_test= train_test_split(X,y,test_size=0.2, random_state=2)

# %%
from sklearn.naive_bayes import GaussianNB, MultinomialNB, BernoulliNB

# %%
gnb= GaussianNB()
mnb= MultinomialNB()
bnb=BernoulliNB()

# %%
gnb.fit(X_train,y_train)
y_pred1= gnb.predict(X_test)
print(accuracy_score(y_test, y_pred1))
print(confusion_matrix(y_test, y_pred1))
print(precision_score(y_test, y_pred1))
# Out:
# 0.8762088974854932
# [[793 103]
#  [ 25 113]]
# 0.5231481481481481

# %%
mnb.fit(X_train,y_train)
y_pred2= mnb.predict(X_test)
print(accuracy_score(y_test, y_pred2))
print(confusion_matrix(y_test, y_pred2))
print(precision_score(y_test, y_pred2))
# Out:
# 0.9593810444874274
# [[896   0]
#  [ 42  96]]
# 1.0

# %%
bnb.fit(X_train,y_train)
y_pred3= bnb.predict(X_test)
print(accuracy_score(y_test, y_pred3))
print(confusion_matrix(y_test, y_pred3))
print(precision_score(y_test, y_pred3))
# Out:
# 0.9700193423597679
# [[893   3]
#  [ 28 110]]
# 0.9734513274336283

# %%
#tfidf= MNB

# %%
from sklearn.svm import SVC

# %%
from sklearn.naive_bayes import MultinomialNB

# %%
temp_df = pd.DataFrame({'Algorithm':clfs.keys(),'Accuracy_max_ft_3000':accuracy_scores,'Precision_max_ft_3000':precision_scores}).sort_values('Precision_max_ft_3000',ascending=False)
# Out:
# ...
#
# ...
#   Obtaining dependency information for scikit-learn from https://files.pythonhosted.org/packages/a8/e9/3e4879974a7c4dcaca2a746dde3df08d0ae8f14c74b03591616ce5f0a8b1/scikit_learn-1.4.0-1-cp311-cp311-win_amd64.whl.metadata
#   Using cached scikit_learn-1.4.0-1-cp311-cp311-win_amd64.whl.metadata (11 kB)
# ...
# Using cached scikit_learn-1.4.0-1-cp311-cp311-win_amd64.whl (10.6 MB)
# ...
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.3.0
#     Uninstalling scikit-learn-1.3.0:
#       Successfully uninstalled scikit-learn-1.3.0
#   Rolling back uninstall of scikit-learn
#   Moving to c:\users\ayush\anaconda3\lib\site-packages\scikit_learn-1.3.0.dist-info\
#    from C:\Users\ayush\anaconda3\Lib\site-packages\~cikit_learn-1.3.0.dist-info
#   Moving to c:\users\ayush\anaconda3\lib\site-packages\sklearn\__check_build\
#    from C:\Users\ayush\anaconda3\Lib\site-packages\sklearn\~_check_build
# ...

# %%
pip install scikit-learn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install scikit-learn==<version_number>
# Out:
# Note: you may need to restart the kernel to use updated packages.
# The syntax of the command is incorrect.

# %%
svc = SVC(kernel='sigmoid', gamma=1.0)

# %%
svc
# Out:
# SVC(gamma=1.0, kernel='sigmoid')

# %%
mnb = MultinomialNB()

# %%
mnb
# Out:
# MultinomialNB()

# %%
temp_df = pd.DataFrame({'Algorithm':clfs.keys(),'Accuracy_max_ft_3000':accuracy_scores,'Precision_max_ft_3000':precision_scores}).sort_values('Precision_max_ft_3000',ascending=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[358], line 1
# ----> 1 temp_df = pd.DataFrame({'Algorithm':clfs.keys(),'Accuracy_max_ft_3000':accuracy_scores,'Precision_max_ft_3000':precision_scores}).sort_values('Precision_max_ft_3000',ascending=False)
#
# NameError: name 'clfs' is not defined
